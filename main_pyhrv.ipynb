# %%
import pandas as pd
import heartpy as hp
import matplotlib.pyplot as plt

sample_rate = 500

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
df = pd.read_csv("MUSE_20211119_134612_49000.csv")
df.columns = [col.strip() for col in df.columns]
df.drop(columns=[""], inplace=True)
df.head()
# Out:
#     I  II  III  aVR  aVL  aVF   V1  V2  V3  V4  V5  V6
# 0 -24 -19    4   21  -14   -7 -244  43 -24 -58 -48 -34
# 1 -53 -24   29   39  -41    2 -244  29 -39 -73 -68 -48
# 2 -19  -4   14   12  -17    4 -248  29 -39 -78 -58 -43
# 3  39  39    0  -39   19   19 -244  39 -34 -63 -43 -29
# 4  14  29   14  -21    0   21 -263  14 -63 -82 -68 -53

# %%
df.shape
# Out:
# (5000, 12)

# %%
df = df / 1000.0

# %%
df.describe()
# Out:
#                  I           II          III          aVR          aVL  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.001446     0.001662     0.000270    -0.001565     0.000577
# std       0.066417     0.131697     0.080363     0.096203     0.033172
# min      -0.209000    -0.258000    -0.117000    -0.722000    -0.200000
# 25%      -0.039000    -0.063000    -0.039000    -0.017000    -0.017000
# 50%      -0.009000    -0.029000    -0.019000     0.019000     0.002000
# 75%       0.024000     0.014000     0.009000     0.046000     0.021000
# max       0.380000     1.063000     0.697000     0.229000     0.109000
#
#                aVF           V1           V2           V3           V4  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.000984     0.008663     0.005109     0.002855    -0.001027
# std       0.103874     0.093465     0.096512     0.416871     0.344654
# min      -0.158000    -0.668000    -0.673000    -2.298000    -1.576000
# 25%      -0.046000    -0.004000    -0.009000    -0.117000    -0.165000
# 50%      -0.024000     0.024000     0.014000    -0.068000    -0.107000
# 75%       0.007000     0.048000     0.043000     0.082000     0.058000
# max       0.873000     0.258000     0.200000     1.093000     1.317000
#
#                 V5           V6
# count  5000.000000  5000.000000
# mean      0.001697     0.002272
# std       0.284399     0.222559
# min      -1.083000    -0.766000
# 25%      -0.122000    -0.092000
# 50%      -0.092000    -0.068000
# 75%      -0.009000    -0.014000
# max       1.498000     1.322000

# %%
import seaborn as sns

sns.lineplot(data=df["V3"][:2500])
# Out:
# <AxesSubplot:ylabel='V3'>

# %%
data = df["V3"]
